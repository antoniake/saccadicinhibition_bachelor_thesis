# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import sem
import os

# %%
from helper import show_velocity_threshold_for_one_file

# %%
input_file = "../data/01/gaze_blocks/split_data_SESSION_2.0_BLOCK_1.0_TRIAL_ORDER_1.0.csv"
column_x = 'X_POS_SCREEN'
column_y = 'Y_POS_SCREEN'
column_t = 'TIME'
noise_factor = 3
plt.xlabel('Time [ms]')
plt.ylabel('Coordinates')
show_velocity_threshold_for_one_file(input_file, column_x, column_y, column_t, noise_factor)

# %%
input_file = "../data/01/gaze_blocks/split_data_SESSION_2.0_BLOCK_1.0_TRIAL_ORDER_2.0.csv"
column_x = 'X_POS_SCREEN'
column_y = 'Y_POS_SCREEN'
column_t = 'TIME'
noise_factor = 3
show_velocity_threshold_for_one_file(input_file, column_x, column_y, column_t, noise_factor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 8
#       5 noise_factor = 3
#       6 show_velocity_threshold_for_one_file(input_file, column_x, column_y, column_t, noise_factor)
# ----> 8 plt.savefig('C:/Users/anton/OneDrive/Dokumente/Bachelorthesis/bristol_project/visualisations/velocity_threshold_noisefactor')
#
# NameError: name 'plt' is not defined

# %%
input_file = "../data/01/gaze_blocks/split_data_SESSION_2.0_BLOCK_1.0_TRIAL_ORDER_3.0.csv"
column_x = 'X_POS_SCREEN'
column_y = 'Y_POS_SCREEN'
column_t = 'TIME'
noise_factor = 3
show_velocity_threshold_for_one_file(input_file, column_x, column_y, column_t, noise_factor)

# %%
input_file = "../data/01/gaze_blocks/split_data_SESSION_2.0_BLOCK_1.0_TRIAL_ORDER_4.0.csv"
column_x = 'X_POS_SCREEN'
column_y = 'Y_POS_SCREEN'
column_t = 'TIME'
noise_factor = 3
show_velocity_threshold_for_one_file(input_file, column_x, column_y, column_t, noise_factor)

# %%
input_file = "../data/03/gaze_blocks/split_data_SESSION_2.0_BLOCK_1.0_TRIAL_ORDER_5.0.csv"
column_x = 'X_POS_SCREEN'
column_y = 'Y_POS_SCREEN'
column_t = 'TIME'
noise_factor = 2
show_velocity_threshold_for_one_file(input_file, column_x, column_y, column_t, noise_factor)

# %%
input_file = "../data/01/gaze_blocks/split_data_SESSION_2.0_BLOCK_1.0_TRIAL_ORDER_6.0.csv"
column_x = 'X_POS_SCREEN'
column_y = 'Y_POS_SCREEN'
column_t = 'TIME'
noise_factor = 3
show_velocity_threshold_for_one_file(input_file, column_x, column_y, column_t, noise_factor)

# %%
input_file = "../data/01/gaze_blocks/split_data_SESSION_2.0_BLOCK_1.0_TRIAL_ORDER_7.0.csv"
column_x = 'X_POS_SCREEN'
column_y = 'Y_POS_SCREEN'
column_t = 'TIME'
noise_factor = 3
show_velocity_threshold_for_one_file(input_file, column_x, column_y, column_t, noise_factor)

# %%
input_file = "../data/01/gaze_blocks/split_data_SESSION_2.0_BLOCK_1.0_TRIAL_ORDER_8.0.csv"
column_x = 'X_POS_SCREEN'
column_y = 'Y_POS_SCREEN'
column_t = 'TIME'
noise_factor = 3
show_velocity_threshold_for_one_file(input_file, column_x, column_y, column_t, noise_factor)

# %%
input_file = "../data/01/gaze_blocks/split_data_SESSION_2.0_BLOCK_1.0_TRIAL_ORDER_9.0.csv"
column_x = 'X_POS_SCREEN'
column_y = 'Y_POS_SCREEN'
column_t = 'TIME'
noise_factor = 3
show_velocity_threshold_for_one_file(input_file, column_x, column_y, column_t, noise_factor)

# %%
input_file = "../data/01/gaze_blocks/split_data_SESSION_2.0_BLOCK_1.0_TRIAL_ORDER_10.0.csv"
column_x = 'X_POS_SCREEN'
column_y = 'Y_POS_SCREEN'
column_t = 'TIME'
noise_factor = 3
show_velocity_threshold_for_one_file(input_file, column_x, column_y, column_t, noise_factor)

# %%
input_file = "../data/01/gaze_blocks/split_data_SESSION_9.0_BLOCK_5.0_TRIAL_ORDER_15.0.csv"
column_x = 'X_POS_SCREEN'
column_y = 'Y_POS_SCREEN'
column_t = 'TIME'
noise_factor = 3
show_velocity_threshold_for_one_file(input_file, column_x, column_y, column_t, noise_factor)

# %%
input_file = "../data/10/gaze_blocks/split_data_SESSION_2.0_BLOCK_1.0_TRIAL_ORDER_1.0.csv"
column_x = 'X_POS_SCREEN'
column_y = 'Y_POS_SCREEN'
column_t = 'TIME'
noise_factor = 3
show_velocity_threshold_for_one_file(input_file, column_x, column_y, column_t, noise_factor)
